# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
import pandas as pd

# import nltk
# nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
finviz_url = 'https://finviz.com/quote.ashx?t='
tickers = ['TSLA', 'AMZN', 'FB']
news_tables = dict()
parsed_data = []

for ticker in tickers:
    
    url = finviz_url + ticker

    #set up response for Beautiful Soup to be able to parse through
    req = Request(url=url, headers={'user-agent':'my-app'})
    response = urlopen(req)

    html = BeautifulSoup(response, 'html')
    news_table = html.find(id='news-table')
    news_tables[ticker] = news_table


for ticker, news_table in news_tables.items():
    
    for row in news_table.findAll('tr'):
        title = row.a.text
        source = row.span.text
        timestamp = row.td.text
        
        date_data = [x.replace('\xa0\xa0', '') for x in timestamp.split(' ')]
        
        if len(date_data) == 1:
            time = date_data[0]
        else:
            date = date_data[0]
            time = date_data[1]
        
        parsed_data.append([ticker, date, time, title, source])

# %%
df = pd.DataFrame(parsed_data, columns=['ticker', 'date', 'time', 'headline', 'source'])
vader = SentimentIntensityAnalyzer()

f = lambda title: vader.polarity_scores(title)['compound']

df['compound'] = df.headline.apply(f)
df['date'] = pd.to_datetime(df.date).dt.date

# %%
df.head()
# Out:
#   ticker        date     time  \
# 0   TSLA  2022-06-13  12:42AM
# 1   TSLA  2022-06-12  11:49PM
# 2   TSLA  2022-06-12  07:41PM
# 3   TSLA  2022-06-12  01:47PM
# 4   TSLA  2022-06-12  09:12AM
#
#                                             headline  \
# 0  Dow Jones Futures Signal Sharp Stock Market Lo...
# 1  China Is Walking Back Virus Loosening Just Wee...
# 2  Lightyear Debuts With Features Other Electric ...
# 3  Elon Musk Takes Sides in the Gender Identity D...
# 4  19-year-old tracking the jets of billionaires:...
#
#                        source  compound
# 0   Investor's Business Daily    -0.765
# 1                   Bloomberg     0.000
# 2               TheStreet.com     0.000
# 3               TheStreet.com     0.000
# 4               Yahoo Finance     0.000
